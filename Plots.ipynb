# %%
# Autogenerated with github copilot
# Stacked bar plot
import numpy as np
import matplotlib.pyplot as plt

N = 5
BlueBars = (20, 35, 30, 35, 27)
YellowBars = (25, 32, 34, 20, 25)
BlueStd = (2, 3, 4, 1, 2)
YellowStd = (3, 5, 2, 3, 3)
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, BlueBars, width, yerr=BlueStd)
p2 = plt.bar(ind, YellowBars, width,
             bottom=BlueBars, yerr=YellowStd)

plt.ylabel('Scores')
plt.title('Stacked Bar')
# Out:
# Text(0.5, 1.0, 'Stacked Bar')

# %%
# Scatter plot with labels next to each point
import numpy as np
import matplotlib.pyplot as plt
Cycles = [1, 2, 3, 4, 5]
Energy = [1, 2, 3, 4, 5]
Configuration = ['32KB', '64KB', '128KB', '256KB', '512KB']
plt.scatter(Cycles, Energy, label=Configuration)
for i, txt in enumerate(Configuration):
    plt.annotate(txt, (x[i], y[i]))
plt.show()
